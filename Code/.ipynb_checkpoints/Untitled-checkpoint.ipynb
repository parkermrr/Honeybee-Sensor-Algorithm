# %%
# Libraries
import numpy as np
import pandas as pd
import scipy.odr as odr
import os
import math
import pdb
import matplotlib.pyplot as plt
import numpy.linalg as la

# def tls(X,y):
    
#     X = np.array([[i, 1] for i in X])
#     y = np.array(y)

#     n = np.array(X).shape[1] 
    
#     Z = np.vstack((X.T,y)).T
#     U, s, Vt = la.svd(Z, full_matrices=True)
    
#     V = Vt.T
#     Vxy = V[:n,n:]
#     Vyy = V[n:,n:]
#     a_tls = - Vxy  / Vyy # total least squares soln
    
#     return a_tls

# Constants
data_dir = '../Data/'
metadata_file = '../Data/Dances_Metadata.csv'
metadata = pd.read_csv(metadata_file)

locs_orig_dir = data_dir + 'Locations/Original/'
locs_orig_files = os.listdir(locs_orig_dir)
locs_orig_files.remove('.DS_Store')
locs_orig_files.sort()

runs_dir = data_dir + '/Runs/'
runs_files = os.listdir(runs_dir)
runs_files.remove('.DS_Store')
runs_files.sort()

def tls(x, y):
    def f(B, x):
        return B[0]*x + B[1]
    linear = odr.Model(f)
    data = odr.Data(x, y)
    fitodr = odr.ODR(data, linear, beta0=[0.1,0.1])
    output = fitodr.run()
    return output.beta
        
class WaggleDance():
    def __init__(self, locs_dir, filename): 
        self.locs_dir = locs_dir
        self.filename = filename
        self.k = 0
        self.h = metadata[metadata['DanceID'] == filename.replace('WaggleDance_', '')[:5]]['AvgBeeLength_Px'].values[0]
        self.dance = pd.read_csv(locs_dir + filename)[['x', 'y']].to_numpy()
        self.classifications = pd.read_csv(locs_dir + filename)[['dance_movement']].to_numpy().flatten()
    
    def getcurrentloc(self):
        if (self.k < len(self.dance)):
            x_k = self.dance[self.k]
            self.k += 1
            return x_k
        return np.array([])
        
    def reset(self):
        self.k = 0

def f(B, x):
    return B[0]*x + B[1]

def angle_from_slope(slope, x_0, x_f):
    potential_angles = []
    if slope > 0:
        potential_angles = [np.arctan(1/slope), np.arctan(1/slope) - math.pi]
    else:
        potential_angles = [np.arctan(1/slope), np.arctan(1/slope) + math.pi]
    travel_vector = np.array(x_f-x_0)
    travel_angle = np.arctan(travel_vector[0]/travel_vector[1])
    diff = potential_angles - travel_angle
    i = np.argmin(diff)
    return potential_angles[i]

# %%
def get_runs_from_dance(dance):
#     pdb.set_trace()
    k = 0
    x_k = dance.getcurrentloc()
    ret = []
    curr_dance = []
    while (len(x_k) != 0):
        if dance.classifications[k] == 1: 
            curr_dance.append(x_k)
        else:
            if len(curr_dance) == 0:
                curr_dance.clear()
            else:
                ret.append(curr_dance.copy())
                curr_dance.clear()
        k += 1
        x_k = dance.getcurrentloc()
    
    if len(curr_dance) != 0:
        ret.append(curr_dance.copy())
        curr_dance.clear()
        
    return ret

def plot_run_with_fit(run):
    data_x = [i[0] for i in run]
    data_y = [-i[1] for i in run]
    
    midpts_x = []
    midpts_y = []
    
    for i in range(1, len(data_x)):
        midpts_x.append((data_x[i] + data_x[i - 1]) / 2)
        midpts_y.append((data_y[i] + data_y[i - 1]) / 2)
    
    linear = odr.Model(f)
    data = odr.Data(data_x, data_y)
    testodr = odr.ODR(data, linear, beta0=[0.1,0.1])
    output = testodr.run()
    
    linear_midpt = odr.Model(f)
    data_midpt = odr.Data(midpts_x, midpts_y)
    testodr_midpt = odr.ODR(data_midpt, linear_midpt, beta0=[0.1,0.1])
    output_midpt = testodr_midpt.run()
    
    y = [f(output.beta, i) for i in range(round(np.array(data_x).min()),round(np.array(data_x).max()))]
    x = [i for i in range(round(np.array(data_x).min()),round(np.array(data_x).max()))]
    midpt_fit_y = [f(output_midpt.beta, i) for i in range(round(np.array(midpts_x).min()),round(np.array(midpts_x).max()))]
    midpt_fit_x = [i for i in range(round(np.array(midpts_x).min()),round(np.array(midpts_x).max()))]
    plt.xlim(np.min(data_x) - 10, np.max(data_x) + 10)
    plt.ylim(np.min(data_y) - 10, np.max(data_y) + 10)
    plt.scatter(data_x, data_y)
    plt.plot(data_x, data_y)
    plt.scatter(midpts_x, midpts_y)
    plt.plot(x,y)
    plt.plot(midpt_fit_x, midpt_fit_y)
    plt.show()
    plt.clf()
    return output_midpt.beta
    
#     plt.xlim(np.min(data_x) + 10, np.max(data_x) + 10)
#     plt.ylim(np.min(data_y) + 10, np.max(data_y) + 10)
#     plt.scatter(data_x, data_y)
#     plt.plot(x,y)
#     plt.show()
#     plt.clf()

# %%
dances = [WaggleDance(locs_orig_dir, file) for file in locs_orig_files]
k = 0

dance_angles_hat = []

for dance in dances:
    print("Plots for dance " + str(k))
    run_angles = []
    for run in get_runs_from_dance(dance):
        run_params = plot_run_with_fit(run)
        x_0, x_f = run[0], run[-1]
        angle = angle_from_slope(run_params[0], x_0, x_f)
        direction = "with" if np.dot(np.array([run_params[0], 1]), np.array(x_f - x_0)) > 0 else "against"
        print("Run angle pre-adjustment: " + str(math.degrees(np.arctan(1/run_params[0]))))
        print("Run direction: " + direction)
        print("Run angle: " + str(math.degrees(angle)))
        print("Run slope: " + str(run_params[0]))
        run_angles.append(math.degrees(angle))
    dance_angles_hat.append(run_angles)
    k += 1
# Out:
# Plots for dance 0
# Run angle pre-adjustment: -88.7594170244417
# Run direction: against
# Run angle: -88.7594170244417
# Run slope: -0.021655641874659542
# Run angle pre-adjustment: 88.78127917213754
# Run direction: against
# Run angle: -91.21872082786246
# Run slope: 0.021273899609634488
# Run angle pre-adjustment: -87.66014184962663
# Run direction: against
# Run angle: -87.66014184962663
# Run slope: -0.04086094670976607
# Plots for dance 1
# Run angle pre-adjustment: 78.79944055453893
# Run direction: with
# Run angle: -101.20055944546107
# Run slope: 0.1980154790079498
# Run angle pre-adjustment: 74.72884214500195
# Run direction: against
# Run angle: -105.27115785499804
# Run slope: 0.27302805339590913
# Run angle pre-adjustment: 57.540886356456355
# Run direction: against
# Run angle: -122.45911364354366
# Run slope: 0.6360674937076369
# Run angle pre-adjustment: -77.82803948883738
# Run direction: against
# Run angle: -77.82803948883738
# Run slope: -0.21569544919902595
# Run angle pre-adjustment: 80.08126652292503
# Run direction: with
# Run angle: -99.91873347707497
# Run slope: 0.17486487821684452
# Run angle pre-adjustment: 78.69940730953728
# Run direction: against
# Run angle: -101.30059269046272
# Run slope: 0.1998304751518647
# Plots for dance 2
# Run angle pre-adjustment: 39.13682683654861
# Run direction: with
# Run angle: -140.8631731634514
# Run slope: 1.2288850453204625
# Run angle pre-adjustment: 60.232931943100915
# Run direction: with
# Run angle: -119.76706805689909
# Run slope: 0.5719423602605239
# Run angle pre-adjustment: 63.51131002218041
# Run direction: against
# Run angle: -116.48868997781959
# Run slope: 0.49833516548721746
# Run angle pre-adjustment: 53.91786098518037
# Run direction: with
# Run angle: -126.08213901481963
# Run slope: 0.7287351534472916
# Run angle pre-adjustment: 66.54892113434398
# Run direction: against
# Run angle: -113.45107886565602
# Run slope: 0.4337974890723835
# Run angle pre-adjustment: 45.10960151792453
# Run direction: against
# Run angle: -134.89039848207545
# Run slope: 0.9961814851017035
# Plots for dance 3
# Run angle pre-adjustment: 65.78176281373256
# Run direction: against
# Run angle: -114.21823718626744
# Run slope: 0.4498004621841074
# Run angle pre-adjustment: 56.684078551650856
# Run direction: against
# Run angle: -123.31592144834914
# Run slope: 0.6572750792588936
# Run angle pre-adjustment: 57.19457466838291
# Run direction: against
# Run angle: -122.8054253316171
# Run slope: 0.6445900479390771
# Plots for dance 4
# Run angle pre-adjustment: 10.861166620530977
# Run direction: against
# Run angle: -169.13883337946902
# Run slope: 5.211948177448967
# Run angle pre-adjustment: 29.53412670004887
# Run direction: against
# Run angle: -150.46587329995114
# Run slope: 1.765040227898168
# Run angle pre-adjustment: 42.33829813698788
# Run direction: against
# Run angle: -137.6617018630121
# Run slope: 1.0975109973647712
# Run angle pre-adjustment: -14.366868042635563
# Run direction: against
# Run angle: -14.366868042635563
# Run slope: -3.904113888035489
# Plots for dance 5
# Run angle pre-adjustment: -23.031846956840102
# Run direction: with
# Run angle: -23.031846956840102
# Run slope: -2.3522163898270825
# Run angle pre-adjustment: -17.59779401718189
# Run direction: against
# Run angle: -17.59779401718189
# Run slope: -3.1528205863268632
# Run angle pre-adjustment: -10.1039022489433
# Run direction: with
# Run angle: -10.1039022489433
# Run slope: -5.6117541840197
# Plots for dance 6
# Run angle pre-adjustment: 9.817866708419617
# Run direction: with
# Run angle: -170.18213329158039
# Run slope: 5.778638391774351
# Run angle pre-adjustment: -7.331895948917317
# Run direction: against
# Run angle: -7.331895948917317
# Run slope: -7.7718906770043485
# Plots for dance 7
# Run angle pre-adjustment: 36.76652347083208
# Run direction: against
# Run angle: -143.23347652916792
# Run slope: 1.3383571456313677
# Run angle pre-adjustment: 67.93756550286861
# Run direction: with
# Run angle: -112.06243449713139
# Run slope: 0.4052943497196162
# Run angle pre-adjustment: 54.07389254865367
# Run direction: against
# Run angle: -125.92610745134634
# Run slope: 0.7245739337098561
# Plots for dance 8
# Run angle pre-adjustment: -79.77065895088639
# Run direction: against
# Run angle: -79.77065895088639
# Run slope: -0.18045712473080808
# Run angle pre-adjustment: -35.96922826688523
# Run direction: with
# Run angle: -35.96922826688523
# Run slope: -1.3779375749718408
# Run angle pre-adjustment: 75.25651570497944
# Run direction: against
# Run angle: -104.74348429502056
# Run slope: 0.26315642899924013
# Run angle pre-adjustment: -71.83740807567688
# Run direction: with
# Run angle: -71.83740807567688
# Run slope: -0.32805995530155463
# Run angle pre-adjustment: -55.83506016433451
# Run direction: with
# Run angle: -55.83506016433451
# Run slope: -0.678705138382974
# Run angle pre-adjustment: -42.61655823137958
# Run direction: with
# Run angle: -42.61655823137958
# Run slope: -1.0868612553664583
# Plots for dance 9
# Run angle pre-adjustment: 41.64635184701616
# Run direction: against
# Run angle: -138.35364815298382
# Run slope: 1.1244934872376826
# Run angle pre-adjustment: 70.99978246436896
# Run direction: against
# Run angle: -109.00021753563104
# Run slope: 0.34433186015222805
# Run angle pre-adjustment: 19.131276013725792
# Run direction: against
# Run angle: -160.8687239862742
# Run slope: 2.8827375480519057
# Run angle pre-adjustment: 31.9376810676946
# Run direction: against
# Run angle: -148.0623189323054
# Run slope: 1.604214555929849
# Run angle pre-adjustment: 35.01234945781984
# Run direction: with
# Run angle: -144.98765054218015
# Run slope: 1.4274930554575562
# Run angle pre-adjustment: 61.647120879180356
# Run direction: against
# Run angle: -118.35287912081964
# Run slope: 0.5396356042381311
# Plots for dance 10
# Run angle pre-adjustment: -66.6625669987513
# Run direction: against
# Run angle: -66.6625669987513
# Run slope: -0.4314427630411232
# Run angle pre-adjustment: 72.119771070875
# Run direction: with
# Run angle: -107.880228929125
# Run slope: 0.32261017263868064
# Run angle pre-adjustment: 72.36684753590903
# Run direction: with
# Run angle: -107.63315246409097
# Run slope: 0.3178556473863609
# Run angle pre-adjustment: 82.25926002727924
# Run direction: against
# Run angle: -97.74073997272075
# Run slope: 0.13592941931568503
# Run angle pre-adjustment: 84.16599680446578
# Run direction: with
# Run angle: -95.83400319553422
# Run slope: 0.10217592300078773
# Run angle pre-adjustment: 67.35626814294682
# Run direction: against
# Run angle: -112.64373185705318
# Run slope: 0.41715562648092885
# Run angle pre-adjustment: -66.37612974974107
# Run direction: with
# Run angle: -66.37612974974107
# Run slope: -0.4373854824786189
# Run angle pre-adjustment: 88.03043267545414
# Run direction: with
# Run angle: -91.96956732454586
# Run slope: 0.034388981201851646
# Run angle pre-adjustment: -82.0016028744869
# Run direction: with
# Run angle: -82.0016028744869
# Run slope: -0.14051230681407595
# Run angle pre-adjustment: 88.48774420664789
# Run direction: against
# Run angle: -91.51225579335211
# Run slope: 0.026399973392320815
# Plots for dance 11
# Run angle pre-adjustment: -42.439724577052104
# Run direction: with
# Run angle: -42.439724577052104
# Run slope: -1.0936160450414003
# Run angle pre-adjustment: -29.32366146343525
# Run direction: against
# Run angle: -29.32366146343525
# Run slope: -1.7802559725498524
# Run angle pre-adjustment: -34.616943751225406
# Run direction: against
# Run angle: -34.616943751225406
# Run slope: -1.448665789300311
# Run angle pre-adjustment: -29.381373321448898
# Run direction: against
# Run angle: -29.381373321448898
# Run slope: -1.7760638996748925
# Run angle pre-adjustment: -51.990135270060804
# Run direction: with
# Run angle: -51.990135270060804
# Run slope: -0.7815629308726286
# Run angle pre-adjustment: -48.00166758896239
# Run direction: against
# Run angle: -48.00166758896239
# Run slope: -0.9003513446052004
# Run angle pre-adjustment: -50.41708789260749
# Run direction: with
# Run angle: -50.41708789260749
# Run slope: -0.8267697207342625
# Run angle pre-adjustment: -31.155334992442167
# Run direction: with
# Run angle: -31.155334992442167
# Run slope: -1.6541049628405775
# Run angle pre-adjustment: -30.74847838847591
# Run direction: against
# Run angle: -30.74847838847591
# Run slope: -1.6809504730948122
# Run angle pre-adjustment: -49.24710906242369
# Run direction: against
# Run angle: -49.24710906242369
# Run slope: -0.8617430480330307
# Run angle pre-adjustment: -37.91630733044879
# Run direction: with
# Run angle: -37.91630733044879
# Run slope: -1.2838025794515013
# Run angle pre-adjustment: -31.390222540336644
# Run direction: against
# Run angle: -31.390222540336644
# Run slope: -1.6388918201101217
# Run angle pre-adjustment: -25.113535126837416
# Run direction: against
# Run angle: -25.113535126837416
# Run slope: -2.133459266824161
# Run angle pre-adjustment: -34.034750061203326
# Run direction: against
# Run angle: -34.034750061203326
# Run slope: -1.4806231220720099
# Run angle pre-adjustment: -34.47986056501445
# Run direction: with
# Run angle: -34.47986056501445
# Run slope: -1.4561052311620017
# Run angle pre-adjustment: -22.60086669447596
# Run direction: with
# Run angle: -22.60086669447596
# Run slope: -2.402243280117128
# Run angle pre-adjustment: -30.00883491308609
# Run direction: against
# Run angle: -30.00883491308609
# Run slope: -1.731434178962825
# Run angle pre-adjustment: -49.871635826820146
# Run direction: with
# Run angle: -49.871635826820146
# Run slope: -0.8429246289690318
# Run angle pre-adjustment: -38.2388051341174
# Run direction: with
# Run angle: -38.2388051341174
# Run slope: -1.2690038595425912
# Run angle pre-adjustment: -52.55168153073204
# Run direction: against
# Run angle: -52.55168153073204
# Run slope: -0.7658948691446672
# Run angle pre-adjustment: -39.1279674449642
# Run direction: with
# Run angle: -39.1279674449642
# Run slope: -1.2292732537286046
# Run angle pre-adjustment: -23.54188224481632
# Run direction: with
# Run angle: -23.54188224481632
# Run slope: -2.2952529081808732
# Run angle pre-adjustment: -40.78162056395369
# Run direction: with
# Run angle: -40.78162056395369
# Run slope: -1.1592627479672648
# Run angle pre-adjustment: -23.972826249019928
# Run direction: against
# Run angle: -23.972826249019928
# Run slope: -2.248906650761189
# Run angle pre-adjustment: -44.17899279754314
# Run direction: with
# Run angle: -44.17899279754314
# Run slope: -1.029077203235537
# Run angle pre-adjustment: -61.35609447417448
# Run direction: against
# Run angle: -61.35609447417448
# Run slope: -0.5462122019796034
# Plots for dance 12
# Run angle pre-adjustment: 62.0935441980752
# Run direction: with
# Run angle: -117.9064558019248
# Run slope: 0.5296170162547674
# Run angle pre-adjustment: 14.215659816038434
# Run direction: with
# Run angle: -165.78434018396155
# Run slope: 3.9474244673977403
# Run angle pre-adjustment: 26.0134859504006
# Run direction: with
# Run angle: -153.9865140495994
# Run slope: 2.049079604651003
# Run angle pre-adjustment: 18.180070460953118
# Run direction: with
# Run angle: -161.81992953904688
# Run slope: 3.0450866630343283
# Run angle pre-adjustment: 26.013159976573505
# Run direction: with
# Run angle: -153.9868400234265
# Run slope: 2.0491091822007035
# Run angle pre-adjustment: 0.9938712556410116
# Run direction: with
# Run angle: -179.006128744359
# Run slope: 57.643313860942754
# Run angle pre-adjustment: 47.989500492942966
# Run direction: with
# Run angle: -132.01049950705703
# Run slope: 0.9007359166171369
# Run angle pre-adjustment: 35.26499690678203
# Run direction: against
# Run angle: -144.73500309321798
# Run slope: 1.4141817686738904
# Plots for dance 13
# Run angle pre-adjustment: -82.40246868477843
# Run direction: against
# Run angle: -82.40246868477843
# Run slope: -0.13338463392972655
# Run angle pre-adjustment: -25.9561567224054
# Run direction: with
# Run angle: -25.9561567224054
# Run slope: -2.054292055523661
# Run angle pre-adjustment: -26.49944837223862
# Run direction: against
# Run angle: -26.49944837223862
# Run slope: -2.0057380672236147
# Run angle pre-adjustment: -51.080929633404494
# Run direction: with
# Run angle: -51.080929633404494
# Run slope: -0.807447975452344
# Run angle pre-adjustment: -49.43668918284062
# Run direction: with
# Run angle: -49.43668918284062
# Run slope: -0.8559935071597172
# Run angle pre-adjustment: -19.40023344216435
# Run direction: with
# Run angle: -19.40023344216435
# Run slope: -2.8396169852933157
# Run angle pre-adjustment: -47.74996914725564
# Run direction: against
# Run angle: -47.74996914725564
# Run slope: -0.9083370292237182

# %%
dance_angles_hat[4]
# Out:
# [-169.13883337946902,
#  -150.46587329995114,
#  -137.6617018630121,
#  -14.366868042635563]

# %%
dance_angles = [pd.read_csv(runs_dir + file)[['RunAngle_Deg']].to_numpy().flatten() for file in runs_files]

# %%
errors_by_dance = []
for k in range(len(dance_angles_hat)):
    dance_pred = dance_angles_hat[k]
    dance_real = dance_angles[k]
    run_errors = []
    for l in range(len(dance_pred)):
        diff = dance_pred[l] - dance_real[l]
        run_errors.append(diff)
    errors_by_dance.append(run_errors)

# %%
all_errors = []
for dance in errors_by_dance:
    for error in dance:
        all_errors.append(error)
all_errors = np.array(all_errors)

# %%
all_errors = all_errors[~np.isnan(all_errors)]

# %%
plt.hist(all_errors)
# Out:
# (array([19., 18.,  0.,  0.,  2., 44.,  7.,  0.,  0.,  1.]),
#  array([-222.70612874, -184.04590609, -145.38568345, -106.7254608 ,
#          -68.06523815,  -29.4050155 ,    9.25520715,   47.9154298 ,
#           86.57565245,  125.2358751 ,  163.89609775]),
#  <BarContainer object of 10 artists>)
