# %% [markdown]
# ## Complete Real-Time Algorithm

# %% [markdown]
# ### Used Variables
#
# \begin{equation}
# h, p, \beta, x, d, \alpha, A, y, i, j, l, w, b, m, s, v
# \end{equation}

# %% [markdown]
# ### Necessary Definitions

# %% [markdown]
# ---
#
# $\hat{h} \in \mathbb{R}$ := The measured length (in pixels) of a honeybee in the video, pre-sampled and averaged across $5$ different time points
#
# ---
#
# $\hat{p} \in (0, 1) $ := The pre-fit probability threshold for the logistic regression model
#
# ---
#
# $\hat{\beta}_0 \in \mathbb{R}$ := The pre-fit logistic regression intercept
#
# $\hat{\beta}_1 \in \mathbb{R}$ := The pre-fit logistic regression coefficient for mean distance
#
# $\hat{\beta}_2 \in \mathbb{R}$ := The pre-fit logistic regression coefficient for mean vertex angle
#
# $\hat{\beta}_3 \in \mathbb{R}$ := The pre-fit logistic regression coefficient for their interaction
#
# $\hat{\beta} = \begin{bmatrix} \hat{\beta}_0 & \hat{\beta}_1 & \hat{\beta}_2 & \hat{\beta}_3 \end{bmatrix}^T \in \mathbb{R}^4$
#
# ---
#
# $y_k \in \left\{ 0, 1 \right\}$ := The actual classification of a honeybee's location at time step $t = k$, where:
# * $y_k = 1$ signifies that the bee is on the waggle *run*, and
# * $y_k = 0$ signifies that the bee is on the *return* phase
#
# ---
#
# $w(l)$, $b_-(l)$, $b_+(l)$, and $m(l)$ are defined (and can be computed prior to program execution for $l = 1, \dots, 6$) as
#
# \begin{align}
# w(l) & = 3l + 2 \\
# b_-(l) & = 2l \\
# b_+(l) & = l + 1 \\
# m(l) & = l - 1 \\
# \end{align}
#
# ---
#
# #### `getcurrentloc()`
#
# The function `getcurrentloc()` returns the current (meaning, at time step $t = k$) location of the honeybee. The location of the honeybee at time step $t = k$ is given by
#
# \begin{equation}
# \overrightarrow{x_k} = \begin{bmatrix} x^{(1)}_k \\ x^{(2)}_k \end{bmatrix} \in \mathbb{R}^2,
# \end{equation}
#
# where $x^{(1)}_k$ is the honeybee's *horizontal* coordinate (in pixels) at time $k$ and $x^{(2)}_k$ is the honeybee's *vertical* coordinate (in pixels) at time $k$.

# %% [markdown]
# ### Algorithm (Expressed Mathematically)

# %% [markdown]
# \begin{align*}
# & \text{while} \left( \left( \overrightarrow{x}_k \leftarrow \text{getcurrentloc()} \right) \neq \text{NULL} \right): \\
# \\
# & \;\;\;\;\; \tilde{x}_k = \left\{ \overrightarrow{x}_{k - 2}, \, \overrightarrow{x}_{k - 1}, \, \overrightarrow{x}_k \right\} & \text{# Location Buffer, as Array} \\
# \\
# & \;\;\;\;\; d_k = \frac{1}{\hat{h}}\cdot\left\Vert \overrightarrow{x}_k - \overrightarrow{x}_{k - 1} \right\Vert_2 \in (0, \approx 1] & \text{# Distance (normalized by bee length)} \\
# & \;\;\;\;\; \tilde{d}_k = \left\{ d_{k - 5}, d_{k - 4}, d_{k - 3}, d_{k - 2}, d_{k - 1}, d_k \right\} & \text{# Distance Buffer, as Array} \\
# \\
# & \;\;\;\;\; \alpha_{k - 1} = \frac{1}{\pi}\cdot\arccos{\left(\frac{\frac{1}{\hat{h}}\cdot\left\Vert \overrightarrow{x}_k - \overrightarrow{x}_{k - 2} \right\Vert_2^2 - d_{k}^2 - d_{k - 1}^2}{2 \cdot d_{k} \cdot d_{k - 1}}\right)} \in [0, 1] & \text{# Suppl. Vertex Angle (computed w/ the Law of Cosines, normalized by $\pi$)} \\
# & \;\;\;\;\; \tilde{\alpha}_k = \left\{ \alpha_{k - 5}, \alpha_{k - 4}, \alpha_{k - 3}, \alpha_{k - 2}, \alpha_{k - 1} \right\} & \text{# Angle Buffer, as Array} \\
# \\
# & \;\;\;\;\; \bar{d}_{k - 3} = \frac{1}{6}\sum_{i = k - 5}^k{d_i} & \text{# Mean Distance} \\
# & \;\;\;\;\; \bar{\alpha}_{k - 3} = \frac{1}{5}\sum_{i = k - 5}^{k - 1}{\alpha_i} & \text{# Mean Angle} \\
# \\
# & \;\;\;\;\; \overrightarrow{A}_{k - 3} = \begin{bmatrix} 1 & \bar{d}_{k - 3} & \bar{\alpha}_{k - 3} & \bar{d}_{k - 3} \cdot \bar{\alpha}_{k - 3} \end{bmatrix}^T \in \mathbb{R}^4 \\
# \\
# & \;\;\;\;\; \hat{y}_{k - 3} = \left\lfloor \left(\frac{1}{1 + e^{-\overrightarrow{A}_{k - 3}^T\hat{\beta}}}\right) + \left(1 - \hat{p}\right)\right\rfloor \in \left\{ 0, 1 \right\} & \text{# Predicted Class using pre-fit Logistic Regression Model} \\
# \\
# & \;\;\;\;\; \tilde{y}_k = \left\{ \hat{y}_{k - 21}, \dots, \hat{y}_{k - 3} \right\} & \text{# Prediction Buffer} \\
# \\
# & \;\;\;\;\; i = k - 3 \\
# & \;\;\;\;\; \text{for } l = 1, \dots, 4: \\
# & \;\;\;\;\; \;\;\;\;\; i = i - b_+(l) \\
# & \;\;\;\;\; \;\;\;\;\; \text{if } l = 4: \\
# & \;\;\;\;\; \;\;\;\;\; \;\;\;\;\; i = i + b_+(3) \\
# & \;\;\;\;\; \;\;\;\;\; s_i = \sum_{j = i - m(l)}^i{\hat{y}_j} \\
# & \;\;\;\;\; \;\;\;\;\; \text{if } \left(\left[\frac{s_i}{l} \text{ mod } 1\right] == 0\right) \text{ and } \left(\hat{y}_{i - m} \neq \hat{y}_{i - m - 1}\right) \text{ and } \left(\hat{y}_i \neq \hat{y}_{i + 1}\right): \\
# & \;\;\;\;\; \;\;\;\;\; \;\;\;\;\; v_i = \left\lfloor \frac{\left[\sum_{j = i - b_-}^{i + b_+}{\hat{y}_j}\right] - s_i}{w(l) - l } + \frac{1}{2} \right\rfloor \\
# & \;\;\;\;\; \;\;\;\;\; \;\;\;\;\; \hat{y}_{i - j} = v_i, \text{for } j = 0, 1, \dots, m(l) \\
# \\
# & \text{# At this point, all pts up through $y_{k - 13}$ have been smoothed} \\
# \end{align*}

# %% [markdown]
# ### Algorithm (Expressed in Code)

# %%
dance = WaggleDance(locs_orig_dir, locs_orig_files[0])
logreg_model = logreg_orig_model

min_run_length = 4
x_buffer = [0] * 22 # { k-21, k-15, ..., k-3, k-2, k-1, k }
d_buffer = [0] * 6 # { k-5, k-4, k-3, k-2, k-1, k }
alpha_buffer = [0] * 5 # { k-5, k-4, k-3, k-2, k-1 }
y_buffer = [0] * 26 # { k-28, ..., k-3 }
curr_run_buffer = []
run_theta = []
run_tau = []

k = 0
x_k = dance.getcurrentloc()
while (len(x_k) != 0):
#     print('Time Step: k = {:d}'.format(k))
    x_buffer.pop(0)
    x_buffer.append(x_k)
    
    ###### Classification algorithm
    
    if k >= 1:
        d_k = euclid_dist(x_k, x_buffer[-2])
        d_buffer.pop(0)
        d_buffer.append(d_k)
        
    if k >= 2: 
        alpha_kminus1 = suppl_vertex_angle(x_k, x_buffer[-3], d_k, d_buffer[-2])
        alpha_buffer.pop(0)
        alpha_buffer.append(alpha_kminus1)

    if k >= 6:
        d_bar_kminus3 = np.mean(d_buffer) / dance.h
        alpha_bar_kminus3 = np.mean(alpha_buffer) / np.pi

        A_kminus3 = np.array([1, d_bar_kminus3, alpha_bar_kminus3, d_bar_kminus3*alpha_bar_kminus3])

        y_hat_kminus3 = logreg_model.predict(A_kminus3)
        y_buffer.pop(0)
        y_buffer.append(y_hat_kminus3)

#         print('Prediction at time k={:d}: {:d}'.format(k - 3, y_hat_kminus3))
    
    ###### Smoothing Algorithm

    if k >= 10: # Boundary for l = 1 (Single)
        smooth_window(y_buffer, l=1, i=23) # i = 23 : Idx of y_hat_kminus5
    
    if k >= 13: # Boundary for l = 2 (Double)
        smooth_window(y_buffer, l=2, i=22) # i = 22 : Idx of y_hat_kminus6
    
    if k >= 18: # Boundary for l = 3 (Triple)
        smooth_window(y_buffer, l=3, i=19) # i = 19 : Idx of y_hat_kminus9
    
    if k >= 21: # Boundary for l = 4 (Quadruple)
        smooth_window(y_buffer, l=4, i=18) # i = 18 : Idx of y_hat_kminus10
        
    if k >= 28: # Boundary for l = 5 (Pentuple)
        smooth_window(y_buffer, l=5, i=13) # i = 13 : Idx of y_hat_kminus15
        
    if k >= 31: # Boundary for l = 6 (Sextuple)
        smooth_window(y_buffer, l=6, i=12) # i = 12 : Idx of y_hat_kminus16
        
    if k < 3: # 0, 1, 2 at times 0, 1, 2
        x_ready = x_buffer[21] # x_k (NOT ACTUALLY READY)
        y_ready = None
        print('Current Time: k={:d}\tPrediction at time k={:d}: None'.format(k, k))
    elif k >= 6 and k < 8: # 3, 4 at times 6, 7
        x_ready = x_buffer[18] # x_{k - 3}
        y_ready = y_buffer[25] # y_{k - 3}
        print('Current Time: k={:d}\tPrediction at time k={:d}: {:d}'.format(k, k - 3, y_ready))
    elif k == 10: # 5 at time 10
        x_ready = x_buffer[16] # x_{k - 5}
        y_ready = y_buffer[23] # y_{k - 5}
        print('Current Time: k={:d}\tPrediction at time k={:d}: {:d}'.format(k, k - 5, y_ready))
    elif k == 13: # 6 at time 13   
        x_ready = x_buffer[14] # x_{k - 7}
        y_ready = y_buffer[21] # y_{k - 7}
        print('Current Time: k={:d}\tPrediction at time k={:d}: {:d}'.format(k, k - 7, y_ready))
    elif k == 18: # 7 at time 18
        x_ready = x_buffer[10] # x_{k - 11}
        y_ready = y_buffer[17] # y_{k - 11}
        print('Current Time: k={:d}\tPrediction at time k={:d}: {:d}'.format(k, k - 11, y_ready))
    elif k == 21: # 8 at time 21
        x_ready = x_buffer[8] # x_{k - 13}
        y_ready = y_buffer[15] # y_{k - 13}
        print('Current Time: k={:d}\tPrediction at time k={:d}: {:d}'.format(k, k - 13, y_ready))
    elif k == 28: # 9 at time 21
        x_ready = x_buffer[2] # x_{k - 19}
        y_ready = y_buffer[9] # y_{k - 19}
        print('Current Time: k={:d}\tPrediction at time k={:d}: {:d}'.format(k, k - 19, y_ready))
    elif k >= 31: # 10, 11, 12, ... at time 21, 22, 23, ..
        x_ready = x_buffer[0] # x_{k - 21}
        y_ready = y_buffer[7] # y_{k - 21}
        print('Current Time: k={:d}\tPrediction at time k={:d}: {:d}'.format(k, k - 21, y_ready))
    
     ###### Total Least Squares

    if k >= 6:
        if y_ready == 1: #check prediction for xkminus_3 (latest prediction)
            curr_run_buffer.append(x_ready) #append xkminus_3
        else:
            if len(curr_run_buffer) <= min_run_length:
                curr_run_buffer.clear()
            else:
                slope, intercept = tls([i[0] for i in curr_run_buffer], [-i[1] for i in curr_run_buffer]) #Negative on the y values to reflect across x-axis
                theta = angle_from_slope(slope, curr_run_buffer[0], curr_run_buffer[-1])
                run_length = len(curr_run_buffer)/30 #Length of run in frames divided by frames per second
#                 print("Run Angle (Radians) = {:.4f} Run Length (Seconds) = {:.4f}".format(theta, run_length))
                run_theta.append(theta)
                run_tau.append(run_length)
                curr_run_buffer.clear()
          
    k += 1
    x_k = dance.getcurrentloc()
    
print('-------------------\t---------------------------')
    
for j in range(21):
    # Note: No l=1 or l=2 window smoothing is necessary (all caught up in prev. while loop)
    if j < 2:
        smooth_window(y_buffer, l=3, i=19 + j + 1) # i = 19 : Idx of y_hat_kminus9
        smooth_window(y_buffer, l=4, i=18 + j + 1) # i = 18 : Idx of y_hat_kminus10
    if j < 6:
        smooth_window(y_buffer, l=5, i=13) # i = 13 : Idx of y_hat_kminus15
        smooth_window(y_buffer, l=6, i=12) # i = 12 : Idx of y_hat_kminus16

    x_ready = x_buffer[0 + j + 1]
    if j < 18:
        y_ready = y_buffer[7 + j + 1]
        print('Current Time: k={:d}\tPrediction at time k={:d}: {:d}'.format(k + j, k - 21 + j, y_ready))
    else: # j = 19, 20, 21 (Last 3 ignored)
        y_ready = None
        print('Current Time: k={:d}\tPrediction at time k={:d}: None'.format(k + j, k - 21 + j))

    ###### Total Least Squares
    if y_ready == 1: #check prediction for xkminus_3 (latest prediction)
        curr_run_buffer.append(x_ready) #append xkminus_3
    else:
        if len(curr_run_buffer) <= min_run_length:
            curr_run_buffer.clear()
        else:
            slope, intercept = tls([i[0] for i in curr_run_buffer], [-i[1] for i in curr_run_buffer]) #Negative on the y values to reflect across x-axis
            theta = theta = angle_from_slope(slope, curr_run_buffer[0], curr_run_buffer[-1]) #1/slope for cotangent
            run_length = len(curr_run_buffer)/30 #Length of run in frames divided by frames per second
#             print("Run Angle (Radians) = {:.4f} Run Length (Seconds) = {:.4f}".format(theta, run_length))
            run_theta.append(theta)
            run_tau.append(run_length)
            curr_run_buffer.clear()
            
if len(run_tau) % 2 != 2: #Ensuring an even number of runs to average over
    run_tau = run_tau[:-1]
    run_theta = run_theta[:-1]
    
theta_bar = np.mean(np.array(run_theta))
tau_bar = np.mean(np.array(run_tau))

print("Run Angle (Degrees) = {:.4f} Run Length (Seconds) = {:.4f}".format(math.degrees(theta_bar), tau_bar))
# Out:
# Current Time: k=0	Prediction at time k=0: None
# Current Time: k=1	Prediction at time k=1: None
# Current Time: k=2	Prediction at time k=2: None
# Current Time: k=6	Prediction at time k=3: 1
# Current Time: k=7	Prediction at time k=4: 1
# Current Time: k=10	Prediction at time k=5: 1
# Current Time: k=13	Prediction at time k=6: 1
# Current Time: k=18	Prediction at time k=7: 1
# Current Time: k=21	Prediction at time k=8: 1
# Current Time: k=28	Prediction at time k=9: 1
# Current Time: k=31	Prediction at time k=10: 1
# Current Time: k=32	Prediction at time k=11: 1
# Current Time: k=33	Prediction at time k=12: 1
# Current Time: k=34	Prediction at time k=13: 1
# Current Time: k=35	Prediction at time k=14: 1
# Current Time: k=36	Prediction at time k=15: 1
# Current Time: k=37	Prediction at time k=16: 1
# Current Time: k=38	Prediction at time k=17: 1
# Current Time: k=39	Prediction at time k=18: 1
# Current Time: k=40	Prediction at time k=19: 1
# Current Time: k=41	Prediction at time k=20: 1
# Current Time: k=42	Prediction at time k=21: 1
# Current Time: k=43	Prediction at time k=22: 1
# Current Time: k=44	Prediction at time k=23: 1
# Current Time: k=45	Prediction at time k=24: 1
# Current Time: k=46	Prediction at time k=25: 1
# Current Time: k=47	Prediction at time k=26: 1
# Current Time: k=48	Prediction at time k=27: 1
# Current Time: k=49	Prediction at time k=28: 1
# Current Time: k=50	Prediction at time k=29: 1
# Current Time: k=51	Prediction at time k=30: 1
# Current Time: k=52	Prediction at time k=31: 1
# Current Time: k=53	Prediction at time k=32: 1
# Current Time: k=54	Prediction at time k=33: 1
# Current Time: k=55	Prediction at time k=34: 1
# Current Time: k=56	Prediction at time k=35: 1
# Current Time: k=57	Prediction at time k=36: 1
# Current Time: k=58	Prediction at time k=37: 1
# Current Time: k=59	Prediction at time k=38: 1
# Current Time: k=60	Prediction at time k=39: 1
# Current Time: k=61	Prediction at time k=40: 1
# Current Time: k=62	Prediction at time k=41: 1
# Current Time: k=63	Prediction at time k=42: 1
# Current Time: k=64	Prediction at time k=43: 1
# Current Time: k=65	Prediction at time k=44: 1
# Current Time: k=66	Prediction at time k=45: 1
# Current Time: k=67	Prediction at time k=46: 1
# Current Time: k=68	Prediction at time k=47: 1
# Current Time: k=69	Prediction at time k=48: 1
# Current Time: k=70	Prediction at time k=49: 1
# Current Time: k=71	Prediction at time k=50: 1
# Current Time: k=72	Prediction at time k=51: 1
# Current Time: k=73	Prediction at time k=52: 1
# Current Time: k=74	Prediction at time k=53: 1
# Current Time: k=75	Prediction at time k=54: 1
# Current Time: k=76	Prediction at time k=55: 1
# Current Time: k=77	Prediction at time k=56: 1
# Current Time: k=78	Prediction at time k=57: 1
# Current Time: k=79	Prediction at time k=58: 1
# Current Time: k=80	Prediction at time k=59: 1
# Current Time: k=81	Prediction at time k=60: 0
# Current Time: k=82	Prediction at time k=61: 0
# Current Time: k=83	Prediction at time k=62: 0
# Current Time: k=84	Prediction at time k=63: 0
# Current Time: k=85	Prediction at time k=64: 0
# Current Time: k=86	Prediction at time k=65: 0
# Current Time: k=87	Prediction at time k=66: 0
# Current Time: k=88	Prediction at time k=67: 0
# Current Time: k=89	Prediction at time k=68: 0
# Current Time: k=90	Prediction at time k=69: 0
# Current Time: k=91	Prediction at time k=70: 0
# Current Time: k=92	Prediction at time k=71: 0
# Current Time: k=93	Prediction at time k=72: 0
# Current Time: k=94	Prediction at time k=73: 0
# Current Time: k=95	Prediction at time k=74: 0
# Current Time: k=96	Prediction at time k=75: 0
# Current Time: k=97	Prediction at time k=76: 0
# Current Time: k=98	Prediction at time k=77: 0
# Current Time: k=99	Prediction at time k=78: 0
# Current Time: k=100	Prediction at time k=79: 0
# Current Time: k=101	Prediction at time k=80: 0
# Current Time: k=102	Prediction at time k=81: 0
# Current Time: k=103	Prediction at time k=82: 0
# Current Time: k=104	Prediction at time k=83: 0
# Current Time: k=105	Prediction at time k=84: 0
# Current Time: k=106	Prediction at time k=85: 0
# Current Time: k=107	Prediction at time k=86: 0
# Current Time: k=108	Prediction at time k=87: 0
# Current Time: k=109	Prediction at time k=88: 0
# Current Time: k=110	Prediction at time k=89: 0
# Current Time: k=111	Prediction at time k=90: 0
# Current Time: k=112	Prediction at time k=91: 0
# Current Time: k=113	Prediction at time k=92: 0
# Current Time: k=114	Prediction at time k=93: 0
# Current Time: k=115	Prediction at time k=94: 0
# Current Time: k=116	Prediction at time k=95: 0
# Current Time: k=117	Prediction at time k=96: 0
# Current Time: k=118	Prediction at time k=97: 0
# Current Time: k=119	Prediction at time k=98: 0
# Current Time: k=120	Prediction at time k=99: 0
# Current Time: k=121	Prediction at time k=100: 0
# Current Time: k=122	Prediction at time k=101: 0
# Current Time: k=123	Prediction at time k=102: 0
# Current Time: k=124	Prediction at time k=103: 0
# Current Time: k=125	Prediction at time k=104: 0
# Current Time: k=126	Prediction at time k=105: 0
# Current Time: k=127	Prediction at time k=106: 0
# Current Time: k=128	Prediction at time k=107: 0
# Current Time: k=129	Prediction at time k=108: 0
# Current Time: k=130	Prediction at time k=109: 0
# Current Time: k=131	Prediction at time k=110: 0
# Current Time: k=132	Prediction at time k=111: 0
# Current Time: k=133	Prediction at time k=112: 0
# Current Time: k=134	Prediction at time k=113: 0
# Current Time: k=135	Prediction at time k=114: 0
# Current Time: k=136	Prediction at time k=115: 0
# Current Time: k=137	Prediction at time k=116: 0
# Current Time: k=138	Prediction at time k=117: 0
# Current Time: k=139	Prediction at time k=118: 0
# Current Time: k=140	Prediction at time k=119: 0
# Current Time: k=141	Prediction at time k=120: 0
# Current Time: k=142	Prediction at time k=121: 0
# Current Time: k=143	Prediction at time k=122: 0
# Current Time: k=144	Prediction at time k=123: 0
# Current Time: k=145	Prediction at time k=124: 0
# Current Time: k=146	Prediction at time k=125: 1
# Current Time: k=147	Prediction at time k=126: 1
# Current Time: k=148	Prediction at time k=127: 1
# Current Time: k=149	Prediction at time k=128: 1
# Current Time: k=150	Prediction at time k=129: 1
# Current Time: k=151	Prediction at time k=130: 1
# Current Time: k=152	Prediction at time k=131: 1
# Current Time: k=153	Prediction at time k=132: 1
# Current Time: k=154	Prediction at time k=133: 1
# Current Time: k=155	Prediction at time k=134: 1
# Current Time: k=156	Prediction at time k=135: 1
# Current Time: k=157	Prediction at time k=136: 1
# Current Time: k=158	Prediction at time k=137: 1
# Current Time: k=159	Prediction at time k=138: 1
# Current Time: k=160	Prediction at time k=139: 1
# Current Time: k=161	Prediction at time k=140: 1
# Current Time: k=162	Prediction at time k=141: 1
# Current Time: k=163	Prediction at time k=142: 1
# Current Time: k=164	Prediction at time k=143: 1
# Current Time: k=165	Prediction at time k=144: 1
# Current Time: k=166	Prediction at time k=145: 1
# Current Time: k=167	Prediction at time k=146: 1
# Current Time: k=168	Prediction at time k=147: 1
# Current Time: k=169	Prediction at time k=148: 1
# Current Time: k=170	Prediction at time k=149: 1
# Current Time: k=171	Prediction at time k=150: 1
# Current Time: k=172	Prediction at time k=151: 1
# Current Time: k=173	Prediction at time k=152: 1
# Current Time: k=174	Prediction at time k=153: 1
# Current Time: k=175	Prediction at time k=154: 1
# Current Time: k=176	Prediction at time k=155: 1
# Current Time: k=177	Prediction at time k=156: 1
# Current Time: k=178	Prediction at time k=157: 1
# Current Time: k=179	Prediction at time k=158: 1
# Current Time: k=180	Prediction at time k=159: 1
# Current Time: k=181	Prediction at time k=160: 1
# Current Time: k=182	Prediction at time k=161: 1
# Current Time: k=183	Prediction at time k=162: 1
# Current Time: k=184	Prediction at time k=163: 1
# Current Time: k=185	Prediction at time k=164: 1
# Current Time: k=186	Prediction at time k=165: 1
# Current Time: k=187	Prediction at time k=166: 1
# Current Time: k=188	Prediction at time k=167: 1
# Current Time: k=189	Prediction at time k=168: 1
# Current Time: k=190	Prediction at time k=169: 1
# Current Time: k=191	Prediction at time k=170: 1
# Current Time: k=192	Prediction at time k=171: 1
# Current Time: k=193	Prediction at time k=172: 1
# Current Time: k=194	Prediction at time k=173: 1
# Current Time: k=195	Prediction at time k=174: 1
# Current Time: k=196	Prediction at time k=175: 1
# Current Time: k=197	Prediction at time k=176: 1
# Current Time: k=198	Prediction at time k=177: 1
# Current Time: k=199	Prediction at time k=178: 1
# Current Time: k=200	Prediction at time k=179: 1
# Current Time: k=201	Prediction at time k=180: 1
# Current Time: k=202	Prediction at time k=181: 1
# Current Time: k=203	Prediction at time k=182: 1
# Current Time: k=204	Prediction at time k=183: 1
# Current Time: k=205	Prediction at time k=184: 1
# Current Time: k=206	Prediction at time k=185: 1
# Current Time: k=207	Prediction at time k=186: 1
# Current Time: k=208	Prediction at time k=187: 1
# Current Time: k=209	Prediction at time k=188: 1
# Current Time: k=210	Prediction at time k=189: 1
# Current Time: k=211	Prediction at time k=190: 1
# Current Time: k=212	Prediction at time k=191: 1
# Current Time: k=213	Prediction at time k=192: 1
# Current Time: k=214	Prediction at time k=193: 1
# Current Time: k=215	Prediction at time k=194: 1
# Current Time: k=216	Prediction at time k=195: 1
# Current Time: k=217	Prediction at time k=196: 1
# Current Time: k=218	Prediction at time k=197: 1
# Current Time: k=219	Prediction at time k=198: 0
# Current Time: k=220	Prediction at time k=199: 0
# Current Time: k=221	Prediction at time k=200: 0
# Current Time: k=222	Prediction at time k=201: 0
# Current Time: k=223	Prediction at time k=202: 0
# Current Time: k=224	Prediction at time k=203: 0
# Current Time: k=225	Prediction at time k=204: 0
# Current Time: k=226	Prediction at time k=205: 0
# Current Time: k=227	Prediction at time k=206: 0
# Current Time: k=228	Prediction at time k=207: 0
# Current Time: k=229	Prediction at time k=208: 0
# Current Time: k=230	Prediction at time k=209: 0
# Current Time: k=231	Prediction at time k=210: 0
# Current Time: k=232	Prediction at time k=211: 0
# Current Time: k=233	Prediction at time k=212: 0
# Current Time: k=234	Prediction at time k=213: 0
# Current Time: k=235	Prediction at time k=214: 0
# Current Time: k=236	Prediction at time k=215: 0
# Current Time: k=237	Prediction at time k=216: 0
# Current Time: k=238	Prediction at time k=217: 0
# Current Time: k=239	Prediction at time k=218: 0
# Current Time: k=240	Prediction at time k=219: 0
# Current Time: k=241	Prediction at time k=220: 0
# Current Time: k=242	Prediction at time k=221: 0
# Current Time: k=243	Prediction at time k=222: 0
# Current Time: k=244	Prediction at time k=223: 0
# Current Time: k=245	Prediction at time k=224: 0
# Current Time: k=246	Prediction at time k=225: 0
# Current Time: k=247	Prediction at time k=226: 0
# Current Time: k=248	Prediction at time k=227: 0
# Current Time: k=249	Prediction at time k=228: 0
# Current Time: k=250	Prediction at time k=229: 0
# Current Time: k=251	Prediction at time k=230: 0
# Current Time: k=252	Prediction at time k=231: 0
# Current Time: k=253	Prediction at time k=232: 0
# Current Time: k=254	Prediction at time k=233: 0
# Current Time: k=255	Prediction at time k=234: 0
# Current Time: k=256	Prediction at time k=235: 0
# Current Time: k=257	Prediction at time k=236: 0
# Current Time: k=258	Prediction at time k=237: 0
# Current Time: k=259	Prediction at time k=238: 0
# Current Time: k=260	Prediction at time k=239: 0
# Current Time: k=261	Prediction at time k=240: 0
# Current Time: k=262	Prediction at time k=241: 0
# Current Time: k=263	Prediction at time k=242: 0
# Current Time: k=264	Prediction at time k=243: 0
# Current Time: k=265	Prediction at time k=244: 0
# -------------------	---------------------------
# Current Time: k=266	Prediction at time k=245: 0
# Current Time: k=267	Prediction at time k=246: 0
# Current Time: k=268	Prediction at time k=247: 0
# Current Time: k=269	Prediction at time k=248: 0
# Current Time: k=270	Prediction at time k=249: 0
# Current Time: k=271	Prediction at time k=250: 0
# Current Time: k=272	Prediction at time k=251: 0
# Current Time: k=273	Prediction at time k=252: 0
# Current Time: k=274	Prediction at time k=253: 0
# Current Time: k=275	Prediction at time k=254: 1
# Current Time: k=276	Prediction at time k=255: 1
# Current Time: k=277	Prediction at time k=256: 1
# Current Time: k=278	Prediction at time k=257: 1
# Current Time: k=279	Prediction at time k=258: 1
# Current Time: k=280	Prediction at time k=259: 1
# Current Time: k=281	Prediction at time k=260: 1
# Current Time: k=282	Prediction at time k=261: 1
# Current Time: k=283	Prediction at time k=262: 1
# Current Time: k=284	Prediction at time k=263: None
# Current Time: k=285	Prediction at time k=264: None
# Current Time: k=286	Prediction at time k=265: None
# Run Angle (Degrees) = -92.5881 Run Length (Seconds) = 2.4667

# %% [markdown]
# ## Necessary Code
#
# (Not central to the algorithm itself, but makes the algorithm appear cleaner. Needs to be run first.)

# %%
# Libraries
import numpy as np
import pandas as pd
import scipy.odr as odr
import os
import math
import pdb

# Constants
data_dir = '../Data/'
metadata_file = '../Data/Dances_Metadata.csv'
metadata = pd.read_csv(metadata_file)

locs_orig_dir = data_dir + 'Locations/Original/'
locs_orig_files = os.listdir(locs_orig_dir)
locs_orig_files.remove('.DS_Store')
locs_orig_files.sort()

all_models = pd.read_csv(data_dir + 'ClassificationModels/LogisticRegression.csv')

# Window Parameters (Constants)
w = {l:(3 * l + 2) for l in range(1, 6 + 1)}
b_lo = {l:(2 * l) for l in range(1, 6 + 1)}
b_hi = {l:(l + 1) for l in range(1, 6 + 1)}
m = {l:(l - 1) for l in range(1, 6 + 1)}

# Universal Functions
def euclid_dist(pt1, pt2):
    d = np.linalg.norm(pt1 - pt2)
    return 0.00001 if np.isclose(d, 0) else d # To correct for numerical error

def suppl_vertex_angle(x_k, x_kminus2, d_k, d_kminus1):
    cos = ((euclid_dist(x_k, x_kminus2))**2 - d_k**2 - d_kminus1**2) / (2 * d_k * d_kminus1)
    cos = 1 if np.isclose(cos, 1) else cos # To correct for numerical error
    cos = -1 if np.isclose(cos, -1) else cos # To correct for numerical error
    return np.arccos(cos)

def smooth_window(y_buffer, l, i):
    s_i = np.sum(y_buffer[(i - m[l]):(i + 1)])
    if (((s_i / l) % 1) == 0) and (y_buffer[i - m[l]] != y_buffer[i - m[l] - 1]) and (y_buffer[i] != y_buffer[i + 1]):
        v_i = ((((np.sum(y_buffer[(i - b_lo[l]):((i + b_hi[l]) + 1)]) - s_i) / (w[l] - l)) + 0.5) // 1)
        for k in range(i - m[l], i + 1):
            y_buffer[k] = int(v_i)

def tls(x, y):
    def f(B, x):
        return B[0]*x + B[1]
    linear = odr.Model(f)
    data = odr.Data(x, y)
    fitodr = odr.ODR(data, linear, beta0=[0.1,0.1])
    output = fitodr.run()
    return output.beta

def angle_from_slope(slope, x_0, x_f):
    in_slope_direction = True if x_f[0] - x_0[0] > 0 else False
    if slope > 0 and in_slope_direction:
        return np.arctan(1/slope)
    elif slope > 0 and not in_slope_direction:
        return np.arctan(1/slope) - math.pi
    elif slope < 0 and in_slope_direction:
        return math.pi + np.arctan(1/slope)
    elif slope < 0 and not in_slope_direction:
        return np.arctan(1/slope)
        
# Classes
class LogisticRegressionModel():
    def __init__(self, prob_threshold, coefs):
        self.p = prob_threshold
        self.beta = coefs
        
    def getprobthreshold(self):
        return self.p
        
    def getcoefs(self):
        return self.beta
    
    def predict(self, X):
        return int((self._probability(X) + (1 - self.p)) // 1)
    
    def _probability(self, X):
        return (1 / (1 + np.exp(-np.dot(X, self.beta))))
        
class WaggleDance():
    def __init__(self, locs_dir, filename): 
        self.locs_dir = locs_dir
        self.filename = filename
        self.k = 0
        self.h = metadata[metadata['DanceID'] == filename.replace('WaggleDance_', '')[:5]]['AvgBeeLength_Px'].values[0]
        self.dance = pd.read_csv(locs_dir + filename)[['x', 'y']].to_numpy()
    
    def getcurrentloc(self):
        if (self.k < len(self.dance)):
            x_k = self.dance[self.k]
            self.k += 1
            return x_k
        return np.array([])
        
    def reset(self):
        self.k = 0

intercept, dist_coef, angle_coef, interact_coef, threshold, _, _, _ = all_models[all_models['Dataset'] == 'OriginalDataset_v8'].to_numpy()[0]
logreg_orig_model = LogisticRegressionModel(threshold, [intercept, dist_coef, angle_coef, interact_coef])

# %% [markdown]
# ---
